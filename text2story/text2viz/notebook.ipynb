# %% [markdown]
# # Text2Viz

# %%
from drs2viz import parser
from text2viz import Text2Viz
import text2story as t2s

BRAT_ANN_DIR = './files/'

# %%
model_loaded=False

# %%
def write_ann_to_file(iso_notation):
    f = open("./files/example.ann", "w")
    for line in enumerate(iso_notation):
        f.write(f'{line[1]}\n')
    f.flush()
    f.close()


def write_txt_to_file(text):
    f = open("./files/example.txt", "w")
    f.write(text)
    f.flush()
    f.close()

# %%
text2viz = Text2Viz('en', '', '2021-12-31')

# %%
language = input(f"Enter language 'pt' for Portuguese or 'en' for English\n")

if language == 'pt':
    text2viz.narrative.lang = 'pt'
elif language == 'en':
    text2viz.narrative.lang = 'en'
else:
    print("Not a valid language. Assuming English")
    text2viz.narrative.lang = 'en'

text = input("Insert Text\n")

text2viz.narrative.text = text

# %%
write_txt_to_file(text2viz.narrative.text)

if not model_loaded:
    print("Loading Models.")

    t2s.start()

    print("Finish Loading Models")

    model_loaded = True

print("Done")
# Out:
# Loading Models.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/ruben/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/ruben/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# pos_ud_bosque download started this may take some time.
# Approximate size to download 2.7 MB
# [OK!]
# pos_anc download started this may take some time.
# Approximate size to download 3.9 MB
# [OK!]
# wikiner_6B_100 download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]
# ner_crf download started this may take some time.
# Approximate size to download 10.2 MB
# [OK!]
# 2021-12-22 17:05:21,708 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2021-12-22 17:05:22,367 - INFO - allennlp.common.file_utils - cache of https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz is up-to-date
# 2021-12-22 17:05:22,373 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz from cache at /home/ruben/.allennlp/cache/0f6b052811b20b13280e609a96efe71ebc636b9c823a5c906ba24459e6e68af9.c1dab61d84cc7c3f7d6751c260040607cb7023a002778ba8f9b9d196b6539174
# 2021-12-22 17:05:22,376 - INFO - allennlp.models.archival - extracting archive file /home/ruben/.allennlp/cache/0f6b052811b20b13280e609a96efe71ebc636b9c823a5c906ba24459e6e68af9.c1dab61d84cc7c3f7d6751c260040607cb7023a002778ba8f9b9d196b6539174 to temp dir /tmp/tmp4slayxrz
# 2021-12-22 17:05:53,819 - INFO - allennlp.common.params - dataset_reader.type = coref
# 2021-12-22 17:05:53,823 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2021-12-22 17:05:53,825 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2021-12-22 17:05:53,827 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2021-12-22 17:05:53,828 - INFO - allennlp.common.params - dataset_reader.max_span_width = 30
# 2021-12-22 17:05:53,831 - INFO - allennlp.common.params - dataset_reader.token_indexers.type = ref
# 2021-12-22 17:05:53,840 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-12-22 17:05:53,842 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-12-22 17:05:53,844 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-12-22 17:05:53,845 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.model_name = SpanBERT/spanbert-large-cased
# 2021-12-22 17:05:53,847 - INFO - allennlp.common.params - type = SpanBERT/spanbert-large-cased
# 2021-12-22 17:05:53,848 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.namespace = tags
# 2021-12-22 17:05:53,850 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.max_length = 512
# 2021-12-22 17:05:53,852 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2021-12-22 17:05:53,873 - INFO - allennlp.common.params - dataset_reader.wordpiece_modeling_tokenizer = None
# 2021-12-22 17:05:53,875 - INFO - allennlp.common.params - dataset_reader.max_sentences = 110
# 2021-12-22 17:05:53,876 - INFO - allennlp.common.params - dataset_reader.remove_singleton_clusters = False
# 2021-12-22 17:05:53,876 - INFO - allennlp.common.params - validation_dataset_reader.type = coref
# 2021-12-22 17:05:53,878 - INFO - allennlp.common.params - validation_dataset_reader.max_instances = None
# 2021-12-22 17:05:53,880 - INFO - allennlp.common.params - validation_dataset_reader.manual_distributed_sharding = False
# 2021-12-22 17:05:53,882 - INFO - allennlp.common.params - validation_dataset_reader.manual_multiprocess_sharding = False
# 2021-12-22 17:05:53,884 - INFO - allennlp.common.params - validation_dataset_reader.max_span_width = 30
# 2021-12-22 17:05:53,887 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.type = ref
# 2021-12-22 17:05:53,892 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-12-22 17:05:53,896 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2021-12-22 17:05:53,899 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-12-22 17:05:53,900 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = SpanBERT/spanbert-large-cased
# 2021-12-22 17:05:53,905 - INFO - allennlp.common.params - type = SpanBERT/spanbert-large-cased
# 2021-12-22 17:05:53,907 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2021-12-22 17:05:53,908 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = 512
# 2021-12-22 17:05:53,910 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2021-12-22 17:05:53,918 - INFO - allennlp.common.params - validation_dataset_reader.wordpiece_modeling_tokenizer = None
# 2021-12-22 17:05:53,919 - INFO - allennlp.common.params - validation_dataset_reader.max_sentences = None
# 2021-12-22 17:05:53,921 - INFO - allennlp.common.params - validation_dataset_reader.remove_singleton_clusters = False
# 2021-12-22 17:05:53,923 - INFO - allennlp.common.params - type = from_instances
# 2021-12-22 17:05:53,925 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmp4slayxrz/vocabulary.
# 2021-12-22 17:05:53,930 - INFO - allennlp.common.params - model.type = coref
# 2021-12-22 17:05:53,937 - INFO - allennlp.common.params - model.regularizer = None
# 2021-12-22 17:05:53,939 - INFO - allennlp.common.params - model.ddp_accelerator = None
# 2021-12-22 17:05:53,941 - INFO - allennlp.common.params - model.text_field_embedder.type = ref
# 2021-12-22 17:05:53,946 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2021-12-22 17:05:53,950 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.type = ref
# 2021-12-22 17:05:53,955 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-12-22 17:05:53,960 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2021-12-22 17:05:53,963 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = SpanBERT/spanbert-large-cased
# 2021-12-22 17:05:53,966 - INFO - allennlp.common.params - type = SpanBERT/spanbert-large-cased
# 2021-12-22 17:05:53,968 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = 512
# 2021-12-22 17:05:53,970 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2021-12-22 17:05:53,973 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.last_layer_only = True
# 2021-12-22 17:05:53,974 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_file = None
# 2021-12-22 17:05:53,975 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_strip_prefix = None
# 2021-12-22 17:05:53,977 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.load_weights = True
# 2021-12-22 17:05:53,978 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.gradient_checkpointing = None
# 2021-12-22 17:05:53,980 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.tokenizer_kwargs = None
# 2021-12-22 17:05:53,982 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.transformer_kwargs = None
# 2021-12-22 17:05:53,984 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.sub_token_mode = avg
# 2021-12-22 17:06:09,275 - INFO - allennlp.common.params - model.context_layer.type = pass_through
# 2021-12-22 17:06:09,290 - INFO - allennlp.common.params - model.context_layer.type = pass_through
# 2021-12-22 17:06:09,292 - INFO - allennlp.common.params - model.context_layer.input_dim = 1024
# 2021-12-22 17:06:09,297 - INFO - allennlp.common.params - model.mention_feedforward.type = ref
# 2021-12-22 17:06:09,339 - INFO - allennlp.common.params - model.mention_feedforward.input_dim = 3092
# 2021-12-22 17:06:09,340 - INFO - allennlp.common.params - model.mention_feedforward.num_layers = 2
# 2021-12-22 17:06:09,340 - INFO - allennlp.common.params - model.mention_feedforward.hidden_dims = 1500
# 2021-12-22 17:06:09,341 - INFO - allennlp.common.params - model.mention_feedforward.activations = relu
# 2021-12-22 17:06:09,341 - INFO - allennlp.common.params - type = relu
# 2021-12-22 17:06:09,342 - INFO - allennlp.common.params - type = relu
# 2021-12-22 17:06:09,343 - INFO - allennlp.common.params - type = relu
# 2021-12-22 17:06:09,343 - INFO - allennlp.common.params - model.mention_feedforward.dropout = 0.3
# 2021-12-22 17:06:09,405 - INFO - allennlp.common.params - model.antecedent_feedforward.type = ref
# 2021-12-22 17:06:09,407 - INFO - allennlp.common.params - model.antecedent_feedforward.input_dim = 9296
# 2021-12-22 17:06:09,408 - INFO - allennlp.common.params - model.antecedent_feedforward.num_layers = 2
# 2021-12-22 17:06:09,408 - INFO - allennlp.common.params - model.antecedent_feedforward.hidden_dims = 1500
# 2021-12-22 17:06:09,409 - INFO - allennlp.common.params - model.antecedent_feedforward.activations = relu
# 2021-12-22 17:06:09,409 - INFO - allennlp.common.params - type = relu
# 2021-12-22 17:06:09,410 - INFO - allennlp.common.params - type = relu
# 2021-12-22 17:06:09,411 - INFO - allennlp.common.params - type = relu
# 2021-12-22 17:06:09,412 - INFO - allennlp.common.params - model.antecedent_feedforward.dropout = 0.3
# 2021-12-22 17:06:09,536 - INFO - allennlp.common.params - model.feature_size = 20
# 2021-12-22 17:06:09,537 - INFO - allennlp.common.params - model.max_span_width = 30
# 2021-12-22 17:06:09,537 - INFO - allennlp.common.params - model.spans_per_word = 0.4
# 2021-12-22 17:06:09,538 - INFO - allennlp.common.params - model.max_antecedents = 50
# 2021-12-22 17:06:09,539 - INFO - allennlp.common.params - model.coarse_to_fine = True
# 2021-12-22 17:06:09,539 - INFO - allennlp.common.params - model.inference_order = 2
# 2021-12-22 17:06:09,540 - INFO - allennlp.common.params - model.lexical_dropout = 0.2
# 2021-12-22 17:06:09,540 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7f52158dcfd0>
# 2021-12-22 17:06:09,745 - INFO - allennlp.nn.initializers - Initializing parameters
# 2021-12-22 17:06:09,751 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-12-22 17:06:09,752 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.0.bias
# 2021-12-22 17:06:09,752 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.0.weight
# 2021-12-22 17:06:09,753 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.1.bias
# 2021-12-22 17:06:09,753 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers
- INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2021-12-22 17:06:49,617 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.dense.bias
# 2021-12-22 17:06:49,617 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.dense.weight
# 2021-12-22 17:06:49,618 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.key.bias
# 2021-12-22 17:06:49,618 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.key.weight
# 2021-12-22 17:06:49,618 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.query.bias
# 2021-12-22 17:06:49,619 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.query.weight
# 2021-12-22 17:06:49,619 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.bias
# 2021-12-22 17:06:49,619 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.weight
# 2021-12-22 17:06:49,619 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.bias
# 2021-12-22 17:06:49,620 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.weight
# 2021-12-22 17:06:49,620 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.bias
# 2021-12-22 17:06:49,620 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.weight
# 2021-12-22 17:06:49,620 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.bias
# 2021-12-22 17:06:49,621 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.weight
# 2021-12-22 17:06:49,621 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.bias
# 2021-12-22 17:06:49,621 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.weight
# 2021-12-22 17:06:49,622 - INFO - allennlp.nn.initializers -    tag_projection_layer.bias
# 2021-12-22 17:06:49,622 - INFO - allennlp.nn.initializers -    tag_projection_layer.weight
# 2021-12-22 17:06:54,704 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmppjbqgzxr
# Finish Loading Models
# Done

# %%
iso_notation = text2viz.sanitize_iso(text2viz.extract_elements())

write_ann_to_file(iso_notation)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# with open(f'./files/example.ann', 'r') as fp:
#   ann_text = fp.readlines()
# self.brat_2_drs(ann_text)

# %%
text2viz.brat_2_drs(iso_notation)
# Out:
#  __________
# | (Is = a) |
# |----------|
# | event(a) |
# |__________|
#  _______________
# | (WasBorn = c) |
# |---------------|
# | event(c)      |
# |_______________|
#  __________
# | (Is = e) |
# |----------|
# | event(e) |
# |__________|
#  __________
# | (Is = g) |
# |----------|
# | event(g) |
# |__________|

# %%
drs_file = parser.get_drs_files(BRAT_ANN_DIR)[0]
filename = drs_file.split('/')[-1].split('_drs')[0]

# %%
text2viz.drs_2_viz_ann_text(filename)
# Out:
# ANN_TEXT:
# -----------------------
# T1 Participant 0 13 Ruben Almeida
#
# A1 Lexical_Head T1 Noun
#
# A2 Individuation_Domain T1 Individual
#
# A3 Participant_Type_Domain T1 Per
#
# A4 Involvement T1 1
#
# T2 Participant 56 61 Porto
#
# A5 Lexical_Head T2 Noun
#
# A6 Individuation_Domain T2 Individual
#
# A7 Participant_Type_Domain T2 Loc
#
# A8 Involvement T2 1
#
# T3 Participant 79 87 Studente
#
# A9 Lexical_Head T3 Noun
#
# A10 Individuation_Domain T3 Individual
#
# A11 Participant_Type_Domain T3 Per
#
# A12 Involvement T3 1
#
# T4 Participant 91 95 FEUP
#
# A13 Lexical_Head T4 Noun
#
# A14 Individuation_Domain T4 Individual
#
# A15 Participant_Type_Domain T4 Per
#
# A16 Involvement T4 1
#
# T5 Participant 97 106 Joe Biden
#
# A17 Lexical_Head T5 Noun
#
# A18 Individuation_Domain T5 Individual
#
# A19 Participant_Type_Domain T5 Per
#
# A20 Involvement T5 1
#
# T7 Participant 41 43 He
#
# A21 Lexical_Head T7 Pronoun
#
# A22 Individuation_Domain T7 Individual
#
# A23 Participant_Type_Domain T7 Other
#
# A24 Involvement T7 1
#
# T8 Participant 71 73 He
#
# A25 Lexical_Head T8 Pronoun
#
# A26 Individuation_Domain T8 Individual
#
# A27 Participant_Type_Domain T8 Other
#
# A28 Involvement T8 1
#
# T9 Participant 17 39 a portuguese young man
#
# A29 Lexical_Head T9 Noun
#
# A30 Individuation_Domain T9 Individual
#
# A31 Participant_Type_Domain T9 Other
#
# A32 Involvement T9 1
#
# T10 Participant 62 69 in 1999
#
# A33 Lexical_Head T10 Noun
#
# A34 Individuation_Domain T10 Individual
#
# A35 Participant_Type_Domain T10 Other
#
# A36 Involvement T10 1
#
# T11 Participant 110 128 American President
#
# A37 Lexical_Head T11 Noun
#
# A38 Individuation_Domain T11 Individual
#
# A39 Participant_Type_Domain T11 Other
#
# A40 Involvement T11 1
#
# T6 Time 65 69 1999
#
# A41 TemporalFunction T6 Publication_Time
#
# T12 Event 14 16 is
#
# E1 EVENT:T12
#
# A42 Class E1 Occurrence
#
# A43 Tense E1 Pres
#
# A44 Polarity E1 Pos
#
# A45 Factuality E1 Factual
#
# T13 Event 44 52 was born
#
# E2 EVENT:T13
#
# A46 Class E2 Occurrence
#
# A47 Tense E2 Pres
#
# A48 Polarity E2 Pos
#
# A49 Factuality E2 Factual
#
# T14 Event 74 76 is
#
# E3 EVENT:T14
#
# A50 Class E3 Occurrence
#
# A51 Tense E3 Pres
#
# A52 Polarity E3 Pos
#
# A53 Factuality E3 Factual
#
# T15 Event 107 109 is
#
# E4 EVENT:T15
#
# A54 Class E4 Occurrence
#
# A55 Tense E4 Pres
#
# A56 Polarity E4 Pos
#
# A57 Factuality E4 Factual
#
# R1 OBJ_REL_objIdentity Arg1:T1 Arg2:T7
#
# R2 OBJ_REL_objIdentity Arg1:T7 Arg2:T8

# %%
text2viz.drs_2_viz_drs_txt(filename)
# Out:
# DRS_TEXT:-----------------------
#
# » EVENTS
#
# # T12 (is) -> a
#
# # FOL:  exists a.event(a)
#
# # DRS:  ([a],[event(a)])
#
#
#
# # T13 (was born) -> c
#
# # FOL:  exists c.event(c)
#
# # DRS:  ([c],[event(c)])
#
#
#
# # T14 (is) -> e
#
# # FOL:  exists e.event(e)
#
# # DRS:  ([e],[event(e)])
#
#
#
# # T15 (is) -> g
#
# # FOL:  exists g.event(g)
#
# # DRS:  ([g],[event(g)])
#
#
#
# » ACTORS
#
# # T1 -> Ruben Almeida
#
# # T7 -> He
#
# # T8 -> He
#
#
#
# » RELATIONS
#
# # T1 - objIdentity - T7
#
# # T7 - objIdentity - T8

# %%
# text2viz.drs_2_viz_msc(filename)

# %%
text2viz.drs_2_viz_graph(filename, False)
# Out:
# Parsing file: ./files/example_drs.txt
#
# ===== ELEMENTS TO DISPLAY =====
#
# ACTORS:
# T8: He, Ruben Almeida, He
#
# EVENTS:
# T12: is
# T13: was born
# T14: is
# T15: is
#
# RELATIONS PER EVENTS:
#
# NON EVENT RELATIONS:
#
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
